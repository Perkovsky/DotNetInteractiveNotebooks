// %%
#r "nuget:Microsoft.DotNet.Interactive.SqlServer,*-*"

// %%
#!connect mssql --create-dbcontext --kernel-name mydatabase "Data Source=.;Database=pl-uat;User ID=sa;Password=111111;"
// Out:
// Scaffolding a `DbContext` and initializing an instance of it called `mydatabase` in the C# kernel.
// Installed package Microsoft.EntityFrameworkCore.Design version 3.1.8
// Kernel added: #!sql-mydatabase

// %%
mydatabase.Amenity.Display();

// %%
var result = await mydatabase.ApiaccessToken.Where(x => x.UserId == 677).ToListAsync();
//result.Explore();
result.Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th>Id</th><th>UserId</th><th>DeviceId</th><th>Token</th><th>Fbtoken</th><th>TokenExp</th><th>SessionExp</th><th>ConnectionId</th><th>User</th></tr></thead><tbody><tr><td>0</td><td><div class="dni-plaintext">2389</div></td><td><div class="dni-plaintext">677</div></td><td></td><td><div class="dni-plaintext">ea5981d1-950b-4c02-8a55-c0acb97367fe</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><span>2020-12-13 08:15:08Z</span></td><td><span>2020-06-22 13:36:42Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>
