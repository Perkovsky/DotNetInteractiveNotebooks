// %%
#r "nuget:Microsoft.DotNet.Interactive.SqlServer,*-*"

// %%
#!connect mssql --kernel-name mydatabase "Data Source=.;Database=pl-uat;User ID=sa;Password=111111;"

// %%
#!sql-mydatabase
SELECT 
    AmenityId,
    BuildingId,
    MAX(AmenityBuilding.id) as ID
FROM 
    AmenityBuilding
GROUP BY 
    AmenityId, BuildingId
ORDER BY
    AmenityId, BuildingId
// Out:
// (46 rows affected)
// <div style="background-color:white;">
// <div id="9a4b5e5eca7945b89a630922c333de0b" style="height: 100ch ;margin: 2px;">
// </div>
// <script type="text/javascript">
//
// let renderNteractDataExplorer_9a4b5e5eca7945b89a630922c333de0b = () => {
//
//     configureRequireFromExtension('nteract','1.0.0')(['nteract/nteractapi'], (nteract) => {
//
//         nteract.createDataExplorer({
//             data: {
//   "profile": "tabular-data-resource",
//   "schema": {
//     "primaryKey": [],
//     "fields": [
//       {
//         "name": "AmenityId",
//         "type": "integer"
//       },
//       {
//         "name": "BuildingId",
//         "type": "integer"
//       },
//       {
//         "name": "ID",
//         "type": "integer"
//       }
//     ]
//   },
//   "data": [
//     {
//       "AmenityId": 5192,
//       "BuildingId": 327,
//       "ID": 17594
//     },
//     {
//       "AmenityId": 5192,
//       "BuildingId": 328,
//       "ID": 17595
// ...
