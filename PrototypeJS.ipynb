// %%
const obj = {
    name: 'Ivan',
    age: 24,
    email: 'ivan@example.com'
}

console.log(obj)
console.log('Name: ' + obj.name)
console.log(`Age: ${obj.age}`)
console.log(3 + 7 + '24' + 11)
// Out:
// <script type="text/javascript">
// if (typeof window.createDotnetInteractiveClient === typeof Function) {
//     window.createDotnetInteractiveClient('http://localhost:57529/').then(async function (interactive) {
//         const console = interactive.getConsole('316');
//         const notebookScope = getDotnetInteractiveScope('http://localhost:57529/');
//         try {
//
// await Object.getPrototypeOf(async function() {}).constructor(
//     "interactive",
//     "console",
//     "notebookScope",
//     "const obj = {\r\n    name: \u0027Ivan\u0027,\r\n    age: 24,\r\n    email: \u0027ivan@example.com\u0027\r\n}\r\n\r\nconsole.log(obj)\r\nconsole.log(\u0027Name: \u0027 + obj.name)\r\nconsole.log(`Age: ${obj.age}`)\r\nconsole.log(3 + 7 + \u002724\u0027 + 11)"
// )(
//     interactive,
//     console,
//     notebookScope
// );
//
//         } catch (err) {
//             interactive.failCommand(err, '316');
//         } finally {
// ...
